# %% [markdown]
# **Ejercicio 5 — Desafío con otro dataset**
# Tarea: Repetir el flujo completo con data/life_expectancy.csv:
#
# Cargar el dataset usando index_col='CountryYear'.
#
# Definir y = 'Life expectancy' y X = el resto (quitar también la columna Status para esta práctica).
#
# Dividir en train/test (80/20, random_state=7).
#
# Estandarizar X_train y aplicar al X_test.
#
# Mostrar la media y desv. estándar de la primera columna de X_train_esc y verificar que sean ≈ 0 y ≈ 1.
#
# Pista: Este dataset tiene valores NaN. Por hoy puedes usar df.dropna() para quitarlos. Mañana veremos formas más elegantes.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('Data/life_expectancy.csv', index_col='CountryYear')

# %%
print("Primeras filas del DataFrame:")
display(df.head(10))

print("Ultimas filas del DataFrame:")
print(df.tail(5))

print("Informacion del DataFrame:")
print(df.info())
# Out:
# Primeras filas del DataFrame:
#                  Status  Life expectancy  Adult Mortality  infant deaths  \
# CountryYear
# Afghanistan2015       0             65.0              263             62
# Afghanistan2014       0             59.9              271             64
# Afghanistan2013       0             59.9              268             66
# Afghanistan2012       0             59.5              272             69
# Afghanistan2011       0             59.2              275             71
# Afghanistan2010       0             58.8              279             74
# Afghanistan2009       0             58.6              281             77
# Afghanistan2008       0             58.1              287             80
# Afghanistan2007       0             57.5              295             82
# Afghanistan2006       0             57.3              295             84
#
#                  Alcohol  percentage expenditure  Hepatitis B  Measles   BMI  \
# CountryYear
# ...

# %%
print("Estadisticas descriptivas del DataFrame:")
print(df.describe())
# Out:
# Estadisticas descriptivas del DataFrame:
#        Status  Life expectancy  Adult Mortality  infant deaths      Alcohol  \
# count  2928.0      2928.000000      2928.000000    2928.000000  2735.000000
# mean      0.0        69.224932       164.796448      30.407445     4.614856
# std       0.0         9.523867       124.292079     118.114450     4.050749
# min       0.0        36.300000         1.000000       0.000000     0.010000
# 25%       0.0        63.100000        74.000000       0.000000     0.905000
# 50%       0.0        72.100000       144.000000       3.000000     3.770000
# 75%       0.0        75.700000       228.000000      22.000000     7.715000
# max       0.0        89.000000       723.000000    1800.000000    17.870000
#
#        percentage expenditure  Hepatitis B        Measles          BMI  \
# count             2928.000000  2375.000000    2928.000000  2896.000000
# mean               740.321185    80.960842    2427.855874    38.235394
# ...

# %%
print("Tipos originales:")
print(df.dtypes)
# Out:
# Tipos originales:
# Status                               int64
# Life expectancy                    float64
# Adult Mortality                      int64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
# BMI                                float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
# HIV/AIDS                           float64
# GDP                                float64
# Population                         float64
# thinness  1-19 years               float64
# thinness 5-9 years                 float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
n_duplicados = df.duplicated().sum()
print(f"Filas duplicadas: {n_duplicados}")
# Out:
# Filas duplicadas: 0

# %%
print("Verificacion de datos nulos:")
print(df.isnull().sum())
# Out:
# Verificacion de datos nulos:
# Status                               0
# Life expectancy                      0
# Adult Mortality                      0
# infant deaths                        0
# Alcohol                            193
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 32
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                443
# Population                         644
# thinness  1-19 years                32
# thinness 5-9 years                  32
# Income composition of resources    160
# Schooling                          160
# dtype: int64

# %%
X = df.drop(columns=['Life expectancy', 'Status'])
y = df['Life expectancy']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

scaler = StandardScaler()
X_train_esc = scaler.fit_transform(X_train)
X_test_esc =  scaler.transform(X_test)

print(f'Media de la primera columna en train: {X_train_esc[:,0].mean():.4f}')
print(f'Desv de la primera columna en train: {X_train_esc[:,0].std():.4f}')
# Out:
# Media de la primera columna en train: -0.0000
# Desv de la primera columna en train: 1.0000
